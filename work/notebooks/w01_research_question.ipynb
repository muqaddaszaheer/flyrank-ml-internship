# %% [markdown]
# <a href="https://colab.research.google.com/github/muqaddaszaheer/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/muqaddaszaheer/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My Lane (or Freestyle) and Why
#
# I chose the Content Optimization lane because I want to analyze content performance data and identify patterns that can help improve search visibility and user engagement. This research is important because it supports better content decisions using real data rather than assumptions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Section 1 Check
# This code confirms that Section 1 has been completed.

print("Section 1 completed.")
# Out:
# Section 1 completed.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## The Question: Decision, Action, Cost of a Wrong Call
#
# This project helps content managers decide which content should be improved to achieve better search performance. Based on the analysis, they can optimize low-performing content. A wrong recommendation could waste time and resources by improving the wrong content or ignoring content that actually needs improvement.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Section 2 Check
# This code confirms that Section 2 has been completed.

print("Section 2 completed.")
# Out:
# Section 2 completed.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ## Quick Look at the Data
#
# The starter dataset contains 30,000 rows and 44 columns. These values indicate that the dataset is large enough to analyze content performance trends and identify useful patterns. The sample records provide an overview of the available features that will support content optimization during the next seven weeks.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

url = "https://raw.githubusercontent.com/muqaddaszaheer/flyrank-ml-internship/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
print(df.head())

print("\nSection 3 completed.")
# Out:
# Number of rows: 30000
# Number of columns: 44
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## Careful Words: What I Can and Can't Claim
#
# This project provides observed patterns and decision support based on the available data. The findings may help identify content that could benefit from optimization. However, this analysis does not prove cause and effect, predict Google's ranking algorithm, or guarantee higher search rankings. The results should be used only to support better content optimization decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Section 4: Careful Words
# This project provides decision support based on observed
# data. It does not prove cause and effect or predict
# Google's ranking algorithm.
print("Section 4: Careful Words\n")

print("This project provides observed patterns and decision support based on the available data.")
print("The results may help identify content that could benefit from optimization.")
print("The analysis does not prove cause and effect.")
print("It does not predict Google's algorithm or guarantee higher search rankings.")
print("The findings should be used to support better content optimization decisions.")

print("\nSection 4 completed successfully.")
# Out:
# Section 4: Careful Words
#
# This project provides observed patterns and decision support based on the available data.
# The results may help identify content that could benefit from optimization.
# The analysis does not prove cause and effect.
# It does not predict Google's algorithm or guarantee higher search rankings.
# The findings should be used to support better content optimization decisions.
#
# Section 4 completed successfully.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
