# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/muqaddaszaheer/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# I selected a classification task. The goal is to classify content into different performance categories using features such as search volume, CTR, average position, and engagement rate. This helps identify which content is performing well and which content may need improvement.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("/content/flyrank-ml-internship/data/raw/content_refresh_anonymized.csv")

print("Dataset Shape:", df.shape)
df.head()
# Out:
# Dataset Shape: (30000, 44)
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# The target is the content performance category. The label comes from the observed data in the dataset, using content performance metrics such as CTR, engagement rate, and search position. This helps predict how content is performing.

# %% [markdown]
# ## 2. Target or proxy
#
# The target is content performance. The label is based on observed values in the dataset, such as CTR, engagement rate, average position, and impression tier. These observed metrics can be used to classify content performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("/content/flyrank-ml-internship/data/raw/content_refresh_anonymized.csv")

target_columns = [
    "ctr",
    "engagement_rate",
    "avg_position",
    "impression_tier"
]

print(df[target_columns].head())
# Out:
#     ctr  engagement_rate  avg_position impression_tier
# 0  0.76             5.88          10.6            good
# 1  0.05             0.00          20.3            good
# 2  0.09             0.00          36.5            good
# 3  0.49             1.28           6.2            good
# 4  0.13             0.00          44.0            good

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# I will use Accuracy as the main success metric. A good model should achieve high accuracy while making reliable predictions on unseen data. Higher accuracy means the model correctly classifies more content.

# %% [markdown]
# ## 3. Success metric
#
# Accuracy will be used as the primary success metric. A higher accuracy means the model correctly classifies more content. Additional metrics such as Precision and Recall may also be useful depending on the final model.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("/content/flyrank-ml-internship/data/raw/content_refresh_anonymized.csv")

print(df["ctr"].describe())
# Out:
# count    30000.000000
# mean         0.510733
# std          3.279162
# min          0.000000
# 25%          0.000000
# 50%          0.070000
# 75%          0.290000
# max        100.000000
# Name: ctr, dtype: float64

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# One row represents one content item. Each row contains information about a single piece of content, including its search volume, CTR, engagement rate, average position, and other related features.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# One row represents one content item. Each row contains information about a single content page, including search volume, CTR, average position, engagement rate, content type, and other related features.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("/content/flyrank-ml-internship/data/raw/content_refresh_anonymized.csv")

columns = [
    "content_id",
    "content_type",
    "search_volume",
    "ctr",
    "avg_position",
    "engagement_rate"
]

df[columns].head()
# Out:
#              content_id     content_type  search_volume   ctr  avg_position  \
# 0  content_304f48230142  keyword article           10.0  0.76          10.6
# 1  content_a1fb4e703a9e  keyword article           90.0  0.05          20.3
# 2  content_9aa793d4d895  keyword article            0.0  0.09          36.5
# 3  content_331d6c4de07b  keyword article           10.0  0.49           6.2
# 4  content_d99b7a2d90ca  keyword article            0.0  0.13          44.0
#
#    engagement_rate
# 0             5.88
# 1             0.00
# 2             0.00
# 3             1.28
# 4             0.00

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# Content performance depends on many features that interact in complex ways. A fixed if-else rule cannot capture these patterns well. Machine learning can learn from historical data and make better predictions based on multiple features together.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# Content performance depends on many factors working together. A simple rule cannot capture these complex relationships. Machine learning can learn patterns from historical data and provide better predictions to support content improvement decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("/content/flyrank-ml-internship/data/raw/content_refresh_anonymized.csv")

numeric_columns = [
    "search_volume",
    "ctr",
    "avg_position",
    "engagement_rate"
]

print(df[numeric_columns].corr())
# Out:
#                  search_volume       ctr  avg_position  engagement_rate
# search_volume         1.000000 -0.003430      0.045354        -0.010146
# ctr                  -0.003430  1.000000     -0.072590         0.096903
# avg_position          0.045354 -0.072590      1.000000        -0.017926
# engagement_rate      -0.010146  0.096903     -0.017926         1.000000

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
