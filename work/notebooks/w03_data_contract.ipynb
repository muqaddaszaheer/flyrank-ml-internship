# %% [markdown]
# <a href="https://colab.research.google.com/github/muqaddaszaheer/flyrank-ml-internship/blob/main/work/notebooks/w03_data_contract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/muqaddaszaheer/flyrank-ml-internship/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# One row represents one content item. Each row contains search performance, engagement, content quality, and SEO metrics for a single content item. The dataset contains 30,000 rows and 53 columns representing the available observation period.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
import glob

# Find all CSV files
import pandas as pd

df = pd.read_csv("sample_data/content_refresh_anonymized.csv")

print("Using: content_refresh_anonymized.csv")
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

print(df.head())
# Out:
# Using: content_refresh_anonymized.csv
# Rows: 30000
# Columns: 53
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
# ...

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# **Features:**
# - Search Volume
# - CTR
# - Engagement Rate
# - Average Position
# - Word Count
# - Scroll Rate
#
# **Label:**
# - Content Performance Category
#
# **Context:**
# - Content Type
# - Main Intent
# - Competition Level
#
# **Excluded:**
# - Client ID
# - Content ID
#
# These fields are excluded because they are identifiers and do not help the model learn content performance patterns.

# %% [markdown]
# **Features:**
# - Search Volume
# - CTR
# - Engagement Rate
# - Average Position
# - Word Count
# - Scroll Rate
#
# **Label:**
# - Content Performance Category
#
# **Context:**
# - Content Type
# - Main Intent
# - Competition Level
#
# **Excluded:**
# - Content ID
# - Client ID
#
# Content ID and Client ID are excluded because they are unique identifiers and do not provide useful information for predicting content performance.

# %% [markdown]
# Features:
# - search_volume
# - competition
# - cpc
# - word_count
# - char_count
# - ctr
# - impressions
# - clicks
# - engaged_sessions
# - avg_position
# - health_score
#
# Label:
# - is_underperformer
#
# Context:
# - content_type
# - main_intent
# - competition_level
#
# Excluded:
# - content_id
# - client_id
#
# Content ID and Client ID are unique identifiers. They identify records but do not help predict content performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Columns in the dataset:")
print(df.columns.tolist())

print("\nSection 2 completed.")
# Out:
# Columns in the dataset:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct', 'health_score', 'needs_indexing', 'is_quick_win', 'needs_ctr_fix', 'needs_engagement_fix', 'ai_opportunity', 'is_underperformer', 'is_declining', 'is_initial_refresh_candidate']
#
# ...

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %% [markdown]
# The dataset should be checked to confirm that each row represents one content item. I will verify the total number of rows and columns, inspect missing values, and review the available fields before starting the analysis.

# %% [markdown]
# I will verify that each row represents one content item by checking the number of rows and columns, reviewing the available fields, and identifying missing values. These checks help confirm that the dataset is suitable for further analysis.

# %% [markdown]
# The dataset was verified by checking the total number of rows and columns, reviewing the available fields, and identifying missing values. These checks confirm that each row represents one content item and help verify the dataset before analysis.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

print("\nMissing values:")
print(df.isnull().sum())

print("\nSection 3 completed.")
# Out:
# Rows: 30000
# Columns: 53
#
# Missing values:
# content_id                          0
# client_id                           0
# search_volume                    2468
# competition                      2468
# competition_level                2610
# cpc                              2468
# content_type                        0
# main_intent                      2374
# word_count                       7699
# char_count                       7699
# provider_used                   21438
# model_used                       5733
# impressions_90d                     0
# clicks_90d                          0
# pageviews_90d                       0
# sessions_90d                        0
# users_90d                           0
# engaged_sessions_90d                0
# ai_sessions_90d                     0
# scroll_events_90d                   0
# days_with_impressions               0
# days_with_sessions                  0
# impressions_last_30d                0
# ...

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %% [markdown]
# This dataset can only describe observed content performance. It cannot prove cause and effect or predict future search engine algorithm changes. The results should be used for decision support rather than making guaranteed conclusions.

# %% [markdown]
# This dataset describes observed content performance based on the available data. It cannot prove cause and effect, predict future Google algorithm changes, or guarantee higher search rankings. The findings should be used as decision support rather than final conclusions.

# %% [markdown]
# This dataset describes observed content performance only. It cannot prove cause and effect, predict future search engine algorithm changes, or guarantee future rankings. The results should be used for decision support rather than final conclusions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Dataset summary:")
print(df.describe(include="all"))

print("\nSection 4 completed.")
# Out:
# Dataset summary:
#                   content_id          client_id  search_volume   competition  \
# count                  30000              30000   27532.000000  27532.000000
# unique                 30000                 32            NaN           NaN
# top     content_6880eb215048  client_19581e27de            NaN           NaN
# freq                       1               7008            NaN           NaN
# mean                     NaN                NaN     158.882391      0.146954
# std                      NaN                NaN    1518.270825      0.285241
# min                      NaN                NaN       0.000000      0.000000
# 25%                      NaN                NaN       0.000000      0.000000
# 50%                      NaN                NaN      10.000000      0.000000
# 75%                      NaN                NaN      20.000000      0.130000
# max                      NaN                NaN   74000.000000      1.000000
#
# ...

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
